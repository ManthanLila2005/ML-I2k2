# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\manth\Downloads\record.csv")
corr1=df.corr(numeric_only=True)
print(corr1)
# Out:
#                  Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Store         1.000000      0.691276      0.030488    -0.124139   -0.495965
# Weekly_Sales  0.691276      1.000000      0.148677    -0.238170   -0.283649
# Holiday_Flag  0.030488      0.148677      1.000000    -0.208987   -0.072119
# Temperature  -0.124139     -0.238170     -0.208987     1.000000    0.162303
# Fuel_Price   -0.495965     -0.283649     -0.072119     0.162303    1.000000
# CPI          -0.509726     -0.257814     -0.029997     0.130804    0.807719
# Unemployment  0.603403      0.389006      0.071360    -0.197610   -0.654127
#
#                    CPI  Unemployment
# Store        -0.509726      0.603403
# Weekly_Sales -0.257814      0.389006
# Holiday_Flag -0.029997      0.071360
# Temperature   0.130804     -0.197610
# Fuel_Price    0.807719     -0.654127
# CPI           1.000000     -0.862473
# Unemployment -0.862473      1.000000

# %%
plt.imshow(corr1,cmap="coolwarm")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df["Fuel_Price"],df["CPI"])
plt.xlabel("Fuel_Price")
plt.ylabel("CPI")
plt.show()

# %%
plt.scatter(df["U"],df["CPI"])
plt.xlabel("Fuel_Price")
plt.ylabel("CPI")
plt.show()
