# %%
#taking input of arrays and creating matrix
import numpy as np
rows =int(input())
cols = int(input())
matrix = []
print("Enter elements row by row:")
for i in range(rows):
    row = list(map(int, input().split()))
    matrix.append(row)
A = np.array(matrix)
print("Matrix A:")
print(A)
# Out:
#  3
#  3
# Enter elements row by row:
#  1 2 3
#  4 5 6
#  7 8 9
# Matrix A:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
#matrix Addition
print(A + A)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]
#  [14 16 18]]

# %%
#matrix Subtraction
print(A-A)
# Out:
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]

# %%
#matrix Multiplication
a=np.dot(A,A)
print(a)
# Out:
# [[ 30  36  42]
#  [ 66  81  96]
#  [102 126 150]]

# %%
print(np.linalg.det(A))
# Out:
# 0.0

# %%
#Matrix Transpose
print(A.T)
# Out:
# [[1 4 7]
#  [2 5 8]
#  [3 6 9]]

# %%
print(np.linalg.inv(A))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(np.linalg.inv(A))
#
# File ~\miniconda3\envs\ml_env\Lib\site-packages\numpy\linalg\_linalg.py:648, in inv(a)
#     645 signature = 'D->D' if isComplexType(t) else 'd->d'
#     646 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     647               over='ignore', divide='ignore', under='ignore'):
# --> 648     ainv = _umath_linalg.inv(a, signature=signature)
#     649 return wrap(ainv.astype(result_t, copy=False))
#
# File ~\miniconda3\envs\ml_env\Lib\site-packages\numpy\linalg\_linalg.py:145, in _raise_linalgerror_singular(err, flag)
#     144 def _raise_linalgerror_singular(err, flag):
# --> 145     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix
